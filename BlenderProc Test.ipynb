# %% [markdown]
# # Install BlenderProc
#
# This chunk of code installs BlenderProc and sets up some things it needs. If you're running this on a local machine follow appropriate install instructions. This works on Colab.

# %%
# !git clone https://github.com/DLR-RM/BlenderProc.git
# %cd "BlenderProc"

# %%
# !pip install -e .

import os

# updating the LD_PRELOAD env variable
os.environ["LD_PRELOAD"] = "/usr/lib/x86_64-linux-gnu/libtcmalloc_minimal.so.4.3.0"

# !blenderproc pip install ipykernel --blender-install-path ./

# %% [markdown]
# # Download Contents
#
# This section will pull in the FRC specific data. This will be used to create the training data

# %%
# !git clone https://github.com/schreiaj/frc-virtual-training-environment.git /content/fvte

# %% [markdown]
# # Run the Training Data Generation
#
# Now this will run it, if you're using different fields or trajectory files (or camera config if I get around to writing that code...) you can update it here

# %%
# %%capture
os.environ["LD_PRELOAD"] = "/usr/lib/x86_64-linux-gnu/libtcmalloc_minimal.so.4.3.0"
# !blenderproc run /content/fvte/main.py /content/fvte/2024/test_path.traj /content/fvte/2024/field_test.blend /content/output --blender-install-path ./

# %% [markdown]
# # Visualize Output

# %%
# %run "-m" "blenderproc" "vis" "hdf5" "/content/output/0.hdf5"

# %% [markdown]
# # Zip and Download

# %%
# !zip -r /content/output.zip /content/output/*

# %%
# !rm -rf /content/output
# Out:
# ERROR: ld.so: object '/usr/lib/x86_64-linux-gnu/libtcmalloc_minimal.so.4.3.0' from LD_PRELOAD cannot be preloaded (cannot open shared object file): ignored.
# ERROR: ld.so: object '/usr/lib/x86_64-linux-gnu/libtcmalloc_minimal.so.4.3.0' from LD_PRELOAD cannot be preloaded (cannot open shared object file): ignored.
